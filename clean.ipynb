# %%
from IPython.core.interactiveshell import InteractiveShell
import numpy as np
import pandas as pd
import seaborn as sns

InteractiveShell.ast_node_interactivity = "all"

# %% [raw]
# ## SPLIT oversized csv
# ! cd data
# ! split -l 4000000 311.csv
# ! mv xaa 311a.csv
# ! mv xab 311b.csv

# %%
df311a = pd.read_csv('data/311a.csv', skiprows=range(1,100), nrows=2)
df311b = pd.read_csv('data/311b.csv', skiprows=range(1,100), nrows=1, header=None)
df311b.columns = df311a.columns
df311 = pd.concat([df311a, df311b])
df311
# Out:
#    Unnamed: 0  Unique Key            Created Date             Closed Date  \
# 0          99    45528488  02/02/2020 09:27:40 AM                     NaN
# 1         100    45531860  02/02/2020 11:33:56 PM                     NaN
# 0     3999999    32525268  01/25/2016 09:54:45 AM  02/02/2016 12:22:51 PM
#
#          Complaint Type         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  RESIDENTIAL BUILDING       11238.0
# 1        HEAT/HOT WATER  RESIDENTIAL BUILDING       11373.0
# 0  UNSANITARY CONDITION  RESIDENTIAL BUILDING       11369.0
#
#         Incident Address      Street Name Address Type           City  Status  \
# 0     500 ST JOHNS PLACE   ST JOHNS PLACE      ADDRESS       BROOKLYN    Open
# 1  89-21 ELMHURST AVENUE  ELMHURST AVENUE      ADDRESS       Elmhurst    Open
# 0        99-21 27 AVENUE        27 AVENUE      ADDRESS  East Elmhurst  Closed
#
#                               Resolution Description   Borough   Latitude  \
# ...
